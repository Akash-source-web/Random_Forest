# %% [markdown]
# # Random_Forest_Assignment_(Company_Data)

# %%
# Import Libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

# %%
#Importing dataset
df=pd.read_csv('C:/Users/Akash Kundu/Desktop/ExcelR/Assingments/Company_Data (1).csv')
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %% [markdown]
# ### EDA

# %%
df.loc[df.Sales>=8.5,'sales']='High'
df.loc[df.Sales<8.5,'sales']='Low'

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US sales
# ...

# %%
df.drop('Sales',inplace=True,axis=1)

# %%
df
# Out:
#      CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0          138      73           11         276    120       Bad   42
# 1          111      48           16         260     83      Good   65
# 2          113      35           10         269     80    Medium   59
# 3          117     100            4         466     97    Medium   55
# 4          141      64            3         340    128       Bad   38
# ..         ...     ...          ...         ...    ...       ...  ...
# 395        138     108           17         203    128      Good   33
# 396        139      23            3          37    120    Medium   55
# 397        162      26           12         368    159    Medium   40
# 398        100      79            7         284     95       Bad   50
# 399        134      37            0          27    120      Good   49
#
#      Education Urban   US sales
# 0           17   Yes  Yes  High
# 1           10   Yes  Yes  High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CompPrice    400 non-null    int64
#  1   Income       400 non-null    int64
#  2   Advertising  400 non-null    int64
#  3   Population   400 non-null    int64
#  4   Price        400 non-null    int64
#  5   ShelveLoc    400 non-null    object
#  6   Age          400 non-null    int64
#  7   Education    400 non-null    int64
#  8   Urban        400 non-null    object
#  9   US           400 non-null    object
#  10  sales        400 non-null    object
# dtypes: int64(7), object(4)
# memory usage: 34.5+ KB

# %%
df.isna().sum()
# Out:
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# sales          0
# dtype: int64

# %%
#finding Unique values and convert these catagorical values into numerical values
df.ShelveLoc.unique()
# Out:
# array(['Bad', 'Good', 'Medium'], dtype=object)

# %%
df['ShelveLoc']=preprocessing.LabelEncoder().fit_transform(df['ShelveLoc'])

# %%
df.Urban.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Urban']=preprocessing.LabelEncoder().fit_transform(df['Urban'])

# %%
df.US.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['US']=preprocessing.LabelEncoder().fit_transform(df['US'])

# %%
df.sales.unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %%
df['sales']=preprocessing.LabelEncoder().fit_transform(df['sales'])

# %%
df
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          0   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          0   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban  US  sales
# 0           17      1   1      0
# 1           10      1   1      0
# ...

# %%
#devide the data into target and predectors
columns=list(df.columns)
predictors=columns[0:10]
target=columns[-1]

# %%
predictors
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'ShelveLoc',
#  'Age',
#  'Education',
#  'Urban',
#  'US']

# %%
target
# Out:
# 'sales'

# %%
X=df[predictors]
Y=df[target]

# %% [markdown]
# ### Model Building

# %%
RF=RandomForestClassifier(n_jobs=2,oob_score=True,n_estimators=1000,criterion='entropy')
RF
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=1000, n_jobs=2,
#                        oob_score=True)

# %% [markdown]
# ### Model prediction

# %%
RF.fit(X,Y)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=1000, n_jobs=2,
#                        oob_score=True)

# %%
RF.estimators_
# Out:
# [DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1249956091),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=889094573),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1982338666),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=2040995824),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1018086251),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=223421431),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=1452440929),
#  DecisionTreeClassifier(criterion='entropy', max_features='auto',
#                         random_state=823403314),
# ...

# %%
RF.classes_
# Out:
# array([0, 1])

# %%
RF.n_features_
# Out:
# 10

# %%
RF.n_outputs_
# Out:
# 1

# %%
df['rf_redict']=RF.predict(X)

# %%
confusion_matrix(df['sales'],df['rf_redict'])
# Out:
# array([[143,   0],
#        [  0, 257]], dtype=int64)

# %% [markdown]
# ### Now will try with 500 decision tress

# %%
RF=RandomForestClassifier(n_jobs=2,n_estimators=500,oob_score=True,criterion='entropy')

# %%
RF.fit(X,Y)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=500, n_jobs=2,
#                        oob_score=True)

# %%
df['rf_predict2']=RF.predict(X)

# %%
confusion_matrix(df['sales'],df['rf_predict2'])
# Out:
# array([[143,   0],
#        [  0, 257]], dtype=int64)
